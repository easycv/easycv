# %% [markdown]
# # Color Examples

# %%
from easycv import Image
from easycv.transforms import GrayScale, FilterChannels

# %% [markdown]
# For this example we will load an image from the [Dog API](https://dog.ceo/dog-api/). For more examples of image loading check [Image examples](../image.ipynb).

# %%
img = Image("https://images.dog.ceo/breeds/germanshepherd/n02106662_5169.jpg")
img
# Out:
# <image size=330x500 at 0x139619597702128>

# %% [markdown]
# ### Gray Scale

# %% [markdown]
# To convert the image to grayscale we just need to apply the transform, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.GrayScale).

# %%
img.apply(GrayScale())
# Out:
# <image size=330x500 at 0x139619527031744>

# %% [markdown]
# ### Filter Channels

# %% [markdown]
# To remove a channel we just need to apply the transform with a list of the channels to remove, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.FilterChannels).

# %%
img.apply(FilterChannels(channels=[1]))
# Out:
# <image size=330x500 at 0x139619611812048>
