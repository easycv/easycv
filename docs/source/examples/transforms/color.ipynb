# %% [markdown]
# # Color Examples

# %%
from easycv import Image
from easycv.transforms import GrayScale, Sepia, FilterChannels, GammaCorrection, Negative, Cartoon, PhotoSketch, ColorTransfer, Hue, Contrast, Brightness, Hsv

# %% [markdown]
# For this example we will load an image with [random()](../../reference/image.rst#easycv.image.Image.random). For more examples of image loading check [Image examples](../image.ipynb).

# %%
img = Image.random()
img
# Out:
# <image size=333x500 at 0x139965331854080>

# %% [markdown]
# ### Gray Scale

# %% [markdown]
# To convert the image to grayscale we just need to apply the transform, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.GrayScale).

# %%
img.apply(GrayScale())
# Out:
# <image size=333x500 at 0x139965326626128>

# %% [markdown]
# ### Sepia

# %% [markdown]
# To convert the image to grayscale we just need to apply the transform, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.Sepia).

# %%
img.apply(Sepia())
# Out:
# <image size=333x500 at 0x139965326664848>

# %% [markdown]
# ### Filter Channels

# %% [markdown]
# To remove a channel we just need to apply the transform with a list of the channels to remove, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.FilterChannels).

# %%
img.apply(FilterChannels(channels=[1]))
# Out:
# <image size=333x500 at 0x139965326666448>

# %% [markdown]
# ### Gamma Correction

# %% [markdown]
# To apply gamma correction we just need to apply the transform with a new gamma value, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.GammaCorrection).

# %%
img.apply(GammaCorrection(gamma=3.0))
# Out:
# <image size=333x500 at 0x139965326678336>

# %%
img.apply(GammaCorrection(gamma=0.5))
# Out:
# <image size=333x500 at 0x139965326677936>

# %% [markdown]
# ### Negative

# %% [markdown]
# To convert the image to negative we just need to apply the transform, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.Negative).

# %%
img.apply(Negative())
# Out:
# <image size=333x500 at 0x139965326625168>

# %% [markdown]
# ### Cartoon

# %% [markdown]
# To make an image look like a Cartoon we just need to apply the transform, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.Cartoon).

# %%
img.apply(Cartoon())
# Out:
# <image size=333x500 at 0x139965326701792>

# %% [markdown]
# ### Photo Sketch

# %% [markdown]
# To make an image look like a pencil sketch we just need to apply the transform, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.PhotoSketch).

# %%
img.apply(PhotoSketch())
# Out:
# <image size=333x500 at 0x139965326703152>

# %% [markdown]
# ### Color Transfer

# %% [markdown]
# To transfer the colors from source to target we just need to apply the transform, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.ColorTransfer).

# %%
src = Image("images/source.jpg")
src
# Out:
# <image size=300x500 at 0x139965326704032>

# %%
img.apply(ColorTransfer(source=src))
# Out:
# <image size=333x500 at 0x139965326718576>

# %% [markdown]
# ### Hue

# %% [markdown]
# To add hue to an image we simply call the Hue transform with the value to add, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.Hue).

# %%
img.apply(Hue(value=50))
# Out:
# <image size=333x500 at 0x139965326720576>

# %% [markdown]
# ### Contrast

# %% [markdown]
# To change the contrast of an image we simply call the Contrast transform with the contrast to add, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.Contrast).

# %%
img.apply(Contrast(alpha=1.6))
# Out:
# <image size=333x500 at 0x139965326740016>

# %% [markdown]
# ### Brightness

# %% [markdown]
# To add Brightness to an image we simply call the Brightness transform with the brightness to add, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.Brightness).

# %%
img.apply(Brightness(beta=50))
# Out:
# <image size=333x500 at 0x139965326734640>

# %% [markdown]
# ### Hsv

# %% [markdown]
# To get the hsv version of an image apply the Hsv transform, for more information check the [reference](../../reference/transforms/color.rst#easycv.transforms.color.Hsv).

# %%
img.apply(Hsv())
# Out:
# <image size=333x500 at 0x139965326736880>
