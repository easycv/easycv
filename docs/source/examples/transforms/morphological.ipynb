# %% [markdown]
# # Morphological Examples

# %%
from easycv import Image
from easycv.transforms import Noise, Erode, Dilate, Morphology

# %% [markdown]
# For this example we will load an example image from the images folder. For more examples of image loading check [Image examples](../image.ipynb).

# %%
img = Image("images/logo.png")
img
# Out:
# <image size=199x726 at 0x140067052339808>

# %% [markdown]
# ### Erode

# %% [markdown]
# Erosion on an image works like soil erosion, it erodes away the boundaries of objects. For more information check the [reference](../../reference/transforms/morphological.rst#easycv.transforms.morphological.Erode).

# %%
img.apply(Erode())
# Out:
# <image size=199x726 at 0x140067052410880>

# %% [markdown]
# ### Dilate

# %% [markdown]
# Dilation is the opposite of erosion. For more information check the [reference](../../reference/transforms/morphological.rst#easycv.transforms.morphological.Dilate).

# %%
img.apply(Dilate())
# Out:
# <image size=199x726 at 0x140067052410800>

# %% [markdown]
# ### Morphology

# %% [markdown]
# We can apply different morphological operations through the various methods of Morphology. For more information check the [reference](../../reference/transforms/morphological.rst#easycv.transforms.morphological.Morphology).

# %% [markdown]
# Let's apply some salt noise to the image

# %%
noisy = img.apply(Noise(method="salt"))
noisy
# Out:
# <image size=199x726 at 0x140067052412160>

# %% [markdown]
# Morphology opening method is very good at removing small random noises like this. Let's apply it to clean the image.

# %%
noisy.apply(Morphology(method="opening"))
# Out:
# <image size=199x726 at 0x140067052412240>

# %% [markdown]
# Let's apply some pepper noise to the image

# %%
noisy = img.apply(Noise(method="pepper", amount=0.2))
noisy
# Out:
# <image size=199x726 at 0x140067052412000>

# %% [markdown]
# Morphology closing method is very good at removing small random noises like this. Let's apply it to clean the image.

# %%
noisy.apply(Morphology(method="closing"))
# Out:
# <image size=199x726 at 0x140067053113216>

# %% [markdown]
# We can also compute things like TopHat (difference between input image and Opening of the image) and BlackHat (difference between the closing of the input image and input image).

# %%
img.apply(Morphology(method="tophat", size=9))
# Out:
# <image size=199x726 at 0x140067052435136>

# %%
img.apply(Morphology(method="blackhat", size=9))
# Out:
# <image size=199x726 at 0x140067052435376>
