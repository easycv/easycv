# %% [markdown]
# # Noise Examples

# %%
from easycv import Image
from easycv.transforms import Noise

# %% [markdown]
# For this example we will load an image from the [Dog API](https://dog.ceo/dog-api/). For more examples of image loading check [Image examples].

# %%
img = Image("https://images.dog.ceo/breeds/terrier-kerryblue/n02093859_798.jpg")
img
# Out:
# <image size=323x250 at 0x140652362586112>

# %% [markdown]
# ### Noise

# %% [markdown]
# To add noise to an image we simply apply the Noise Transform with the desired method, for more information check the [reference](../../reference/transforms/noise.rst).

# %%
img.apply(Noise(method="gaussian"))
# Out:
# <image size=323x250 at 0x140652370087168>

# %%
img.apply(Noise(method="s&p"))
# Out:
# <image size=323x250 at 0x140652356611088>
