# %% [markdown]
# # Noise Examples

# %%
from easycv import Image
from easycv.transforms import Noise

# %% [markdown]
# For this example we will load an image with [random()](../../reference/image.rst#easycv.image.Image.random). For more examples of image loading check [Image examples](../image.ipynb).

# %%
img = Image.random()
img
# Out:
# <image size=202x175 at 0x139619468889664>

# %% [markdown]
# ### Noise

# %% [markdown]
# To add noise to an image we simply apply the Noise Transform with the desired method, for more information check the [reference](../../reference/transforms/noise.rst#easycv.transforms.noise.Noise).

# %%
img.apply(Noise(method="gaussian"))
# Out:
# <image size=202x175 at 0x139619459789808>

# %%
img.apply(Noise(method="sp"))
# Out:
# <image size=202x175 at 0x139619434117040>
