# %% [markdown]
# # Spatial Examples

# %%
from easycv import Image
from easycv.transforms import Resize, Rescale, Rotate, Crop, Translate

# %% [markdown]
# For this example we will load an image from the [Dog API](https://dog.ceo/dog-api/). For more examples of image loading check [Image examples].

# %%
img = Image("https://images.dog.ceo/breeds/terrier-bedlington/n02093647_2376.jpg")
img
# Out:
# <image size=375x500 at 0x139619526489872>

# %% [markdown]
# ### Resize

# %% [markdown]
# To resize an image we simply apply the Rezise Transform, for more information check the [reference](../../reference/transforms/spatial.rst).

# %%
img.apply(Resize(width=500, height=500))
# Out:
# <image size=500x500 at 0x139619526491152>

# %% [markdown]
# ### Rescale

# %% [markdown]
# To rescale an image we simply apply the Rescale Transform with the factors of x and y, for more information check the [reference](../../reference/transforms/spatial.rst).

# %%
img.apply(Rescale(fx=0.5, fy=1))
# Out:
# <image size=375x250 at 0x139619527077936>

# %% [markdown]
# ### Rotate

# %% [markdown]
# To rotate an image we simply apply the Rotate Transform with the degrees to rotate, for more information check the [reference](../../reference/transforms/spatial.rst).

# %%
img.apply(Rotate(degrees=50))
# Out:
# <image size=624x608 at 0x139619527078816>

# %% [markdown]
# ### Crop

# %% [markdown]
# To crop an image we simply apply the Crop Transform with the boundaries of each side, for more information check the [reference](../../reference/transforms/spatial.rst).

# %%
img.apply(Crop(box=[200,300,100,200],original=False))
# Out:
# <image size=100x100 at 0x139619527120016>

# %% [markdown]
# ### Translate

# %% [markdown]
# To translate an image we simply apply the Translate Transform with the vector to translate, for more information check the [reference](../../reference/transforms/spatial.rst).

# %%
img.apply(Translate(x=10,y=50))
# Out:
# <image size=375x500 at 0x139619526113440>
